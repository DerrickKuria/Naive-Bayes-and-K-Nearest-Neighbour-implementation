# %% [markdown]
# # 1. Defining the Question

# %% [markdown]
# **1. Title:  SPAM E-mail Database**
#
#
#
# > The Dataset is a compiled **Mark Hopkins**, **Erik Reeber**,**George Forman** and **Jaap Suermondt.**
#
#
#
# > The dataset was brought together to assist to know whether some emails are categorised as Spam messages.

# %% [markdown]
# ## a. Specifying the question

# %% [markdown]
# Email spam, also known as junk email, is unsolicited bulk messages sent through email.
#
# The "spam" concept is diverse: advertisements for products/web sites, make money fast schemes, chain letters, pornography.
#
# To recognize spam ,we will be using Natural Language Processing and Naive Bayes to help categorize the data as Spam or not spam.

# %% [markdown]
# ## b. Defining the metric of success

# %% [markdown]
# The dataset definately has Spam messages. By having a high accuracy to recognize the spam messages will be best metric of success in this project.

# %% [markdown]
# ## c. Understanding the context

# %% [markdown]
# ## d. Recording the experiment design

# %% [markdown]
# We shall be using the following:
#
# 1.  ***NLP*** - Natural Language Processing is the technology used to aid computers to understand the human’s natural language.
# 2.   ***Naive Bayes*** - It is a classification technique based on Bayes’ Theorem with an assumption of independence among predictors. In simple terms, a Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature.

# %% [markdown]
# ## e. Data Relevance

# %% [markdown]
# The data is very relevant.

# %% [markdown]
# # **2. Read Data**

# %% [markdown]
# ## **a. Import the Dependencies**

# %%
#Numpy is a library for python that supports multidimensional arrays and matrices as well as mathematical functions
import numpy as np
#Pandas is Python library used for data manipulation and data analysis
import pandas as pd
#Matplotlib is a python library utilised in plotting and its numerical capabilities
import matplotlib.pyplot as plt
#Seaborn is a Python data visualisation library based on matplotlib.
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## **b. Import the Data**

# %%
#We will use read_csv function from pandas to load the spam dataset
df = pd.read_csv('/content/spam.csv')

# %% [markdown]
# # **3.Checking our Data**

# %%
#We will first inspect the head of the dataset.
df.head()
# Out:
#    wor1d_freq_make:  ...  capital_run_length_total:
# 0              0.00  ...                          1
# 1              0.21  ...                          1
# 2              0.06  ...                          1
# 3              0.00  ...                          1
# 4              0.00  ...                          1
#
# [5 rows x 58 columns]

# %%
#We will also check the last 5 items of the dataset to check for the consistency of the dataset
df.tail()
# Out:
#       wor1d_freq_make:  ...  capital_run_length_total:
# 4596              0.31  ...                          0
# 4597              0.00  ...                          0
# 4598              0.30  ...                          0
# 4599              0.96  ...                          0
# 4600              0.00  ...                          0
#
# [5 rows x 58 columns]

# %%
#Numpy array version of our data
df.values
# Out:
# array([[0.000e+00, 6.400e-01, 6.400e-01, ..., 6.100e+01, 2.780e+02,
#         1.000e+00],
#        [2.100e-01, 2.800e-01, 5.000e-01, ..., 1.010e+02, 1.028e+03,
#         1.000e+00],
#        [6.000e-02, 0.000e+00, 7.100e-01, ..., 4.850e+02, 2.259e+03,
#         1.000e+00],
#        ...,
#        [3.000e-01, 0.000e+00, 3.000e-01, ..., 6.000e+00, 1.180e+02,
#         0.000e+00],
#        [9.600e-01, 0.000e+00, 0.000e+00, ..., 5.000e+00, 7.800e+01,
#         0.000e+00],
#        [0.000e+00, 0.000e+00, 6.500e-01, ..., 5.000e+00, 4.000e+01,
#         0.000e+00]])

# %%
# we will also check the shape of the data i.e ( number of columns and Rows)
print('The total number of rows in the Email spam dataset is : \n{}'.format(df.shape[0]))
print('The total number of columns in the Email spam dataset is: \n {}'.format(df.shape[1]))
# Out:
# The total number of rows in the Email spam dataset is :
# 4601
# The total number of columns in the Email spam dataset is:
#  58

# %%
#Checking our Indexing Start to end using sttribute Index.
df.index
# Out:
# RangeIndex(start=0, stop=4601, step=1)

# %%
# we will check the data attribute columns.
df.columns
#our 58 columns are displayed below.
# Out:
# Index(['wor1d_freq_make:', 'word_freq_address:', 'word_freq_all:',
#        'word_freq_3d:', 'word_freq_our:', 'word_freq_over:',
#        'word_freq_remove:', 'word_freq_internet:', 'word_freq_order:',
#        'word_freq_mail:', 'word_freq_mail:.1', 'word_freq_receive:',
#        'word_freq_will:', 'word_freq_people:', 'word_freq_report:',
#        'word_freq_addresses:', 'word_freq_free:', 'word_freq_business:',
#        'word_freq_email:', 'word_freq_you:', 'word_freq_credit:',
#        'word_freq_your:', 'word_freq_font:', 'word_freq_000:',
#        'word_freq_money:', 'word_freq_hp:', 'word_freq_hpl:',
#        'word_freq_george:', 'word_freq_650:', 'word_freq_lab:',
#        'word_freq_labs:', 'word_freq_telnet:', 'word_freq_857:',
#        'word_freq_data:', 'word_freq_415:', 'word_freq_85:',
#        'word_freq_technology:', 'word_freq_1999:', 'word_freq_parts:',
#        'word_freq_pm:', 'word_freq_direct:', 'word_freq_cs:',
# ...

# %%
#Checking at the info of our DataFrame
df.info()

#We have noticed
#1.that our data does not have missing Data.
#2.Tthat our data datatypes is in float form( Decimals)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   wor1d_freq_make:             4601 non-null   float64
#  1   word_freq_address:           4601 non-null   float64
#  2   word_freq_all:               4601 non-null   float64
#  3   word_freq_3d:                4601 non-null   float64
#  4   word_freq_our:               4601 non-null   float64
#  5   word_freq_over:              4601 non-null   float64
#  6   word_freq_remove:            4601 non-null   float64
#  7   word_freq_internet:          4601 non-null   float64
#  8   word_freq_order:             4601 non-null   float64
#  9   word_freq_mail:              4601 non-null   float64
#  10  word_freq_mail:.1            4601 non-null   float64
#  11  word_freq_receive:           4601 non-null   float64
# ...

# %%
#Check  for repetition of the number of different items in the columns.
print (df.nunique())
# Out:
# wor1d_freq_make:                142
# word_freq_address:              171
# word_freq_all:                  214
# word_freq_3d:                    43
# word_freq_our:                  255
# word_freq_over:                 141
# word_freq_remove:               173
# word_freq_internet:             170
# word_freq_order:                144
# word_freq_mail:                 245
# word_freq_mail:.1               113
# word_freq_receive:              316
# word_freq_will:                 158
# word_freq_people:               133
# word_freq_report:               118
# word_freq_addresses:            253
# word_freq_free:                 197
# word_freq_business:             229
# word_freq_email:                575
# word_freq_you:                  148
# word_freq_credit:               401
# word_freq_your:                  99
# word_freq_font:                 164
# word_freq_000:                  143
# word_freq_money:                395
# word_freq_hp:                   281
# ...

# %%
#obtaining the Mathematical Data Summaries.(mean, std ,Minimum , Maximum and the Quartiles.)
df.describe()
# Out:
#        wor1d_freq_make:  ...  capital_run_length_total:
# count       4601.000000  ...                4601.000000
# mean           0.104553  ...                   0.394045
# std            0.305358  ...                   0.488698
# min            0.000000  ...                   0.000000
# 25%            0.000000  ...                   0.000000
# 50%            0.000000  ...                   0.000000
# 75%            0.000000  ...                   1.000000
# max            4.540000  ...                   1.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# # ***4.External Data Source Validation***
#
#
# Making sure your data matches something outside of the dataset is very important. It allows you to ensure that the measurements are roughly in line with what they should be and it serves as a check on what other things might be wrong in your dataset. External validation can often be as simple as checking your data against a single number, as we will do here.

# %% [markdown]
# ## ***i. Outliers***

# %%
#We can also use a function to check the outliers
# Cheking for outliers using boxplots.

integers =['wor1d_freq_make:', 'word_freq_address:', 'word_freq_all:',
       'word_freq_3d:', 'word_freq_our:', 'word_freq_over:',
       'word_freq_remove:', 'word_freq_internet:', 'word_freq_order:',
       'word_freq_mail:', 'word_freq_mail:.1', 'word_freq_receive:',
       'word_freq_will:', 'word_freq_people:', 'word_freq_report:',
       'word_freq_addresses:', 'word_freq_free:', 'word_freq_business:',
       'word_freq_email:', 'word_freq_you:', 'word_freq_credit:',
       'word_freq_your:', 'word_freq_font:', 'word_freq_000:',
       'word_freq_money:', 'word_freq_hp:', 'word_freq_hpl:',
       'word_freq_george:', 'word_freq_650:', 'word_freq_lab:',
       'word_freq_labs:', 'word_freq_telnet:', 'word_freq_857:',
       'word_freq_data:', 'word_freq_415:', 'word_freq_85:',
       'word_freq_technology:', 'word_freq_1999:', 'word_freq_parts:',
       'word_freq_pm:', 'word_freq_direct:', 'word_freq_cs:',
       'word_freq_meeting:', 'word_freq_original:', 'word_freq_project:',
       'word_freq_re:', 'word_freq_edu:', 'word_freq_table:',
       'word_freq_conference:', 'char_freq_;:', 'char_freq_(:', 'char_freq_[:',
       'char_freq_!:', 'char_freq_$:', 'char_freq_#:',
       'capital_run_length_average:', 'capital_run_length_longest:',
       'capital_run_length_total:']
for i, j in enumerate(integers):
  plt.figure(figsize=(8,5))
  plt.title(j)
  sns.boxplot(df[j])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %% [markdown]
# We seem to have a lot of outliers. We will use Z-score to drop the Data points that are too far away.
#
#
# The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured.
#
# The intuition behind Z-score is to describe any data point by finding their relationship with the Standard Deviation and Mean of the group of data points.
#
# In most of the cases a **threshold of 3 or -3** is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
print(z)
# Out:
# [[0.34243371 0.3308849  0.71285877 ... 0.04529792 0.00872413 1.24007366]
#  [0.3453594  0.05190919 0.43512954 ... 0.25056283 1.22832407 1.24007366]
#  [0.14592139 0.16507191 0.85172339 ... 2.22110599 3.25873251 1.24007366]
#  ...
#  [0.64012787 0.16507191 0.03837349 ... 0.23694133 0.27262775 0.80640371]
#  [2.80176333 0.16507191 0.55676058 ... 0.24207296 0.33860365 0.80640371]
#  [0.34243371 0.16507191 0.73269658 ... 0.24207296 0.40128076 0.80640371]]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([   2,    2,    2, ..., 4592, 4593, 4594]), array([14, 22, 56, ...,  4, 45, 29]))

# %%
print(z[55][1])
# Out:
# 0.16507191215585587

# %%
df = df[(z < 3).all(axis=1)]

# %%
df.shape
# Out:
# (2185, 58)

# %% [markdown]
# We have reduced the outliers by the Z-score.
# Let us inspect using Percentiles.

# %%
#Outlier detection using the percentiles
import matplotlib.pyplot as plt

def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

integers =['wor1d_freq_make:', 'word_freq_address:', 'word_freq_all:',
       'word_freq_3d:', 'word_freq_our:', 'word_freq_over:',
       'word_freq_remove:', 'word_freq_internet:', 'word_freq_order:',
       'word_freq_mail:', 'word_freq_mail:.1', 'word_freq_receive:',
       'word_freq_will:', 'word_freq_people:', 'word_freq_report:',
       'word_freq_addresses:', 'word_freq_free:', 'word_freq_business:',
       'word_freq_email:', 'word_freq_you:', 'word_freq_credit:',
       'word_freq_your:', 'word_freq_font:', 'word_freq_000:',
       'word_freq_money:', 'word_freq_hp:', 'word_freq_hpl:',
       'word_freq_george:', 'word_freq_650:', 'word_freq_lab:',
       'word_freq_labs:', 'word_freq_telnet:', 'word_freq_857:',
       'word_freq_data:', 'word_freq_415:', 'word_freq_85:',
       'word_freq_technology:', 'word_freq_1999:', 'word_freq_parts:',
       'word_freq_pm:', 'word_freq_direct:', 'word_freq_cs:',
       'word_freq_meeting:', 'word_freq_original:', 'word_freq_project:',
       'word_freq_re:', 'word_freq_edu:', 'word_freq_table:',
       'word_freq_conference:', 'char_freq_;:', 'char_freq_(:', 'char_freq_[:',
       'char_freq_!:', 'char_freq_$:', 'char_freq_#:',
       'capital_run_length_average:', 'capital_run_length_longest:',
       'capital_run_length_total:']

fig, ax = plt.subplots(len(integers), figsize=(10,50))

for i, col_val in enumerate(integers):
    y = df[col_val][:1000]
    sns.distplot(y, ax=ax[i], rug=True, hist=False)
    outliers = y[percentile_based_outlier(y)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

# %% [markdown]
# # **5. Exploratory Data Analysis**

# %% [markdown]
# ## a. Univariate
#
#
# ---
#
#
# Univariate is a term commonly used in statistics to describe a type of data which consists of observations on only a single characteristic or attribute

# %%
# Plot histogram for numerical values

for i, j in enumerate(integers):
  plt.figure(figsize=(8, 5))
  plt.title(j)
  sns.distplot(df[j], color='red', norm_hist=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# ## **b. Bivariate**

# %% [markdown]
# Bivariate analysis is one of the simplest forms of quantitative analysis. It involves the analysis of two variables, for the purpose of determining the empirical relationship between them

# %% [markdown]
# i).Correlation

# %%
# Create a correlation matrix 
corrMatrix = df.corr()
corrMatrix

# Vizualise the correlation matrix using a heat map

fig, ax = plt.subplots(figsize=(25,25)) 
sns.heatmap(corrMatrix,  linewidths=.5, ax=ax)

# %% [markdown]
# ## c.Multivariate Analysis
#
#
# ---
#
#
# Is used to understand and reduce the data dimensions by analysing the data covariance structure.

# %% [markdown]
# # **6. Implementing the solution**

# %% [markdown]
# ## **a.Splitting the Data**

# %%
# We will split our data into our independent and dependent variables using our columns
test_features = ['wor1d_freq_make:', 'word_freq_address:', 'word_freq_all:',
       'word_freq_3d:', 'word_freq_our:', 'word_freq_over:',
       'word_freq_remove:', 'word_freq_internet:', 'word_freq_order:',
       'word_freq_mail:', 'word_freq_mail:.1', 'word_freq_receive:',
       'word_freq_will:', 'word_freq_people:', 'word_freq_report:',
       'word_freq_addresses:', 'word_freq_free:', 'word_freq_business:',
       'word_freq_email:', 'word_freq_you:', 'word_freq_credit:',
       'word_freq_your:', 'word_freq_font:', 'word_freq_000:',
       'word_freq_money:', 'word_freq_hp:', 'word_freq_hpl:',
       'word_freq_george:', 'word_freq_650:', 'word_freq_lab:',
       'word_freq_labs:', 'word_freq_telnet:', 'word_freq_857:',
       'word_freq_data:', 'word_freq_415:', 'word_freq_85:',
       'word_freq_technology:', 'word_freq_1999:', 'word_freq_parts:',
       'word_freq_pm:', 'word_freq_direct:', 'word_freq_cs:',
       'word_freq_meeting:', 'word_freq_original:', 'word_freq_project:',
       'word_freq_re:', 'word_freq_edu:', 'word_freq_table:',
       'word_freq_conference:', 'char_freq_;:', 'char_freq_(:', 'char_freq_[:',
       'char_freq_!:', 'char_freq_$:', 'char_freq_#:',
       'capital_run_length_average:','capital_run_length_longest:']

# %%
X = df[test_features].values
y = df['capital_run_length_total:'].values

# %% [markdown]
# ## **b. Implementing the Naive Bayes algorithm**

# %%
#import Gaussian NB and Metrics for accuracy.
from sklearn import metrics 
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import ComplementNB

# %% [markdown]
# Creating Our Naive Bayes Model Using Sckit-learn using a function.

# %% [markdown]
# ## **c. Evaluating the model**

# %% [markdown]
# ---
#
#
# **Accuracy** measures how often the classifier makes the correct prediction
#
#
# ---
#
#
# **Precision** tells us what proportion of messages we classified as spam
#
#
# ---

# %% [markdown]
# We are going to test mutiple splits in the Data and we will start with 80 % by 20%

# %% [markdown]
# > `First Split 80:20`

# %%
# Splitting our data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=25)

# %%
print('Number of rows in the total set: {}'.format(df.shape[0]))
print('Number of rows in the training  set: {}'.format(X_train.shape[0]))
print('Number of rows in the test set: {}'.format(X_test.shape[0]))
# Out:
# Number of rows in the total set: 2185
# Number of rows in the training  set: 1748
# Number of rows in the test set: 437

# %%
def main():
    model = GaussianNB()
    model.fit(X_train,y_train)
    predicted= model.predict( X_test )
    print("The Accuracy score is:",metrics.accuracy_score( y_test, predicted ))
    print("The Precision Score is:",metrics.precision_score( y_test, predicted ))
    print("The Recall Score is:",metrics.recall_score( y_test, predicted ))
    print("The F1  score is:",metrics.f1_score( y_test, predicted ))
main()
# Out:
# The Accuracy score is: 0.7123287671232876
# The Precision Score is: 0.5625
# The Recall Score is: 0.9113924050632911
# The F1  score is: 0.6956521739130435

# %% [markdown]
# With a 80% train , 20% test data, we get a 74 % accuracy.

# %% [markdown]
# > `Second Split: 70:30`

# %%
# Splitting our data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=25)

# %%
print('Number of rows in the total set: {}'.format(df.shape[0]))
print('Number of rows in the training  set: {}'.format(X_train.shape[0]))
print('Number of rows in the test set: {}'.format(X_test.shape[0]))
# Out:
# Number of rows in the total set: 2185
# Number of rows in the training  set: 1529
# Number of rows in the test set: 656

# %%
def main():
    model = GaussianNB()
    model.fit(X_train,y_train)
    predicted= model.predict( X_test )
    print("Accuracy:",metrics.accuracy_score( y_test, predicted ))
    print("The Precision Score is:",metrics.precision_score( y_test, predicted ))
    print("The Recall Score is:",metrics.recall_score( y_test, predicted ))
    print("The F1  score is:",metrics.f1_score( y_test, predicted ))
main()
# Out:
# Accuracy: 0.7545731707317073
# The Precision Score is: 0.6206896551724138
# The Recall Score is: 0.9285714285714286
# The F1  score is: 0.7440381558028617

# %% [markdown]
# With 70 % train and 30 % test the accuracy rises to around 76 %.

# %% [markdown]
# > `Third Split 60:40`

# %%
# Splitting our data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.4, random_state=25)

# %%
def main():
    model = GaussianNB()
    model.fit(X_train,y_train)
    predicted= model.predict( X_test )
    print("Accuracy:",metrics.accuracy_score( y_test, predicted ))
    print("The Precision Score is:",metrics.precision_score( y_test, predicted ))
    print("The Recall Score is:",metrics.recall_score( y_test, predicted ))
    print("The F1  score is:",metrics.f1_score( y_test, predicted ))
main()
# Out:
# Accuracy: 0.7545731707317073
# The Precision Score is: 0.6206896551724138
# The Recall Score is: 0.9285714285714286
# The F1  score is: 0.7440381558028617

# %% [markdown]
# the accuracy did not improve as much.

# %% [markdown]
# > `Fourth Split 90:10`

# %%
# Splitting our data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=25)

# %%
def main():
    model = GaussianNB()
    model.fit(X_train,y_train)
    predicted= model.predict( X_test )
    print("Accuracy:",metrics.accuracy_score( y_test, predicted ))
    print("The Precision Score is:",metrics.precision_score( y_test, predicted ))
    print("The Recall Score is:",metrics.recall_score( y_test, predicted ))
    print("The F1  score is:",metrics.f1_score( y_test, predicted ))
main()
# Out:
# Accuracy: 0.7545731707317073
# The Precision Score is: 0.6206896551724138
# The Recall Score is: 0.9285714285714286
# The F1  score is: 0.7440381558028617

# %% [markdown]
# Here we will create a classification report that contains the various statistics required to judge a model. After that, we will create a confusion matrix which will give us a clear idea of the accuracy and the fitting of the model.

# %% [markdown]
# # **7.Challenging the Solution**

# %%
#We need to drop the ourliers in a more organised way to achieve higher accuracy scores

# %% [markdown]
# # **8. Follow up questions**

# %% [markdown]
# *At this point, we can refine our question or collect new data, all in an iterative process to get at the truth.*

# %% [markdown]
# ## a). Did we have the right data?

# %%
#Yes. The data was fine. Had the required number Rows and Columns. It was sufficient for this experiment.

# %% [markdown]
# ## b). Do we need other data to answer our question?

# %%
#Sure. This data was sufficient to answer the question.

# %% [markdown]
# ## c). Did we have the right question?

# %%
#Yes , we had a dataset that had a collection of Spam messages and we were trying a model and an accuracy to determine 
#Spam and not spam
